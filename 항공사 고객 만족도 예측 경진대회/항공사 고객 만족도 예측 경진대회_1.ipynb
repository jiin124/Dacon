# %% [markdown]
# <a href="https://colab.research.google.com/github/jiin124/Dacon/blob/main/%ED%95%AD%EA%B3%B5%EC%82%AC%20%EA%B3%A0%EA%B0%9D%20%EB%A7%8C%EC%A1%B1%EB%8F%84%20%EC%98%88%EC%B8%A1%20%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8C/%ED%95%AD%EA%B3%B5%EC%82%AC%20%EA%B3%A0%EA%B0%9D%20%EB%A7%8C%EC%A1%B1%EB%8F%84%20%EC%98%88%EC%B8%A1%20%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8C_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv('/content/drive/MyDrive/airline_dataset/train.csv')
test=pd.read_csv('/content/drive/MyDrive/airline_dataset/test.csv')
sample=pd.read_csv('/content/drive/MyDrive/airline_dataset/sample_submission.csv')

# %%
train.head()
# Out:
#    id  Gender  ... Arrival Delay in Minutes  target
# 0   1  Female  ...                      0.0       0
# 1   2  Female  ...                     18.0       0
# 2   3    Male  ...                      0.0       1
# 3   4  Female  ...                      2.0       0
# 4   5  Female  ...                      0.0       1
#
# [5 rows x 24 columns]

# %%
test.head()
# Out:
#    id  Gender  ... Departure Delay in Minutes  Arrival Delay in Minutes
# 0   1  Female  ...                         51                      58.0
# 1   2  Female  ...                          0                       0.0
# 2   3  Female  ...                          0                       0.0
# 3   4    Male  ...                          0                       0.0
# 4   5  Female  ...                          0                       0.0
#
# [5 rows x 23 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 3000 non-null   int64
#  1   Gender                             3000 non-null   object
#  2   Customer Type                      3000 non-null   object
#  3   Age                                3000 non-null   int64
#  4   Type of Travel                     3000 non-null   object
#  5   Class                              3000 non-null   object
#  6   Flight Distance                    3000 non-null   int64
#  7   Seat comfort                       3000 non-null   int64
#  8   Departure/Arrival time convenient  3000 non-null   int64
#  9   Food and drink                     3000 non-null   int64
#  10  Gate location                      3000 non-null   int64
#  11  Inflight wifi service              3000 non-null   int64
#  12  Inflight entertainment             3000 non-null   int64
#  13  Online support                     3000 non-null   int64
#  14  Ease of Online booking             3000 non-null   int64
#  15  On-board service                   3000 non-null   int64
#  16  Leg room service                   3000 non-null   int64
#  17  Baggage handling                   3000 non-null   int64
#  18  Checkin service                    3000 non-null   int64
#  19  Cleanliness                        3000 non-null   int64
#  20  Online boarding                    3000 non-null   int64
#  21  Departure Delay in Minutes         3000 non-null   int64
#  22  Arrival Delay in Minutes           3000 non-null   float64
#  23  target                             3000 non-null   int64
# dtypes: float64(1), int64(19), object(4)
# memory usage: 562.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 2000 non-null   int64
#  1   Gender                             2000 non-null   object
#  2   Customer Type                      2000 non-null   object
#  3   Age                                2000 non-null   int64
#  4   Type of Travel                     2000 non-null   object
#  5   Class                              2000 non-null   object
#  6   Flight Distance                    2000 non-null   int64
#  7   Seat comfort                       2000 non-null   int64
#  8   Departure/Arrival time convenient  2000 non-null   int64
#  9   Food and drink                     2000 non-null   int64
#  10  Gate location                      2000 non-null   int64
#  11  Inflight wifi service              2000 non-null   int64
#  12  Inflight entertainment             2000 non-null   int64
#  13  Online support                     2000 non-null   int64
#  14  Ease of Online booking             2000 non-null   int64
#  15  On-board service                   2000 non-null   int64
#  16  Leg room service                   2000 non-null   int64
#  17  Baggage handling                   2000 non-null   int64
#  18  Checkin service                    2000 non-null   int64
#  19  Cleanliness                        2000 non-null   int64
#  20  Online boarding                    2000 non-null   int64
#  21  Departure Delay in Minutes         2000 non-null   int64
#  22  Arrival Delay in Minutes           2000 non-null   float64
# dtypes: float64(1), int64(18), object(4)
# memory usage: 359.5+ KB

# %%
train.drop('id',axis=1,inplace=True)
test.drop('id',axis=1,inplace=True)

# %% [markdown]
# ## EDA

# %%
train.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Gate location', 'Inflight wifi service',
#        'Inflight entertainment', 'Online support', 'Ease of Online booking',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'target'],
#       dtype='object')

# %%
sns.countplot(data=train,x='Gender',hue='target')

# %% [markdown]
# 여성의 만족도가 남성의 만족도보다 더 높다.

# %%
sns.countplot(data=train,x='Customer Type',hue='target')

# %% [markdown]
# Loyal customer이 역시나 만족도가 좋다. disloyal이면 불만족이 더 크다.

# %%
sns.countplot(data=train,x='Type of Travel',hue='target')

# %% [markdown]
# 비지니스용일 때 만족도가 높고, 개인적으로 이용할 때는 불만족이 더 높다.

# %%
sns.countplot(data=train,x='Class',hue='target')

# %% [markdown]
# 역시 비지니스석이 만족도비율이 가장 높다.

# %%
sns.countplot(data=train,x='Departure/Arrival time convenient',hue='target')

# %% [markdown]
# 출발,도착 시간 편의성 만족도가 높을수록 대개 만족도가 높다. 만족도를 4로 한 사람들이 가장 많은 것도 알 수 있다.

# %%
sns.countplot(data=train,x='Food and drink',hue='target')

# %% [markdown]
# 식음료 만족도와 만족도가 연계성이 꽤 높을 것 같다는 생각이 든다. 만족도가 높을 수록 만족도의 비율이 크고, 식음료 만족도가 낮을 수록 만족도의 비율이 낮다.

# %%
sns.countplot(data=train,x='Gate location',hue='target')

# %% [markdown]
# 딱히 관계성이 없어보인다. 게이트 위치 만족도가 낮아도 만족도가 높은 사람들이 있었다.

# %%
sns.countplot(data=train,x='Inflight wifi service',hue='target')

# %% [markdown]
# 역시 와이파이는 중요하다.

# %%
sns.countplot(data=train,x='Inflight entertainment',hue='target')

# %% [markdown]
# 기내 엔터테인먼트 만족도는 만족도와 큰 연관성을 가질 것이라 생각이 든다. 엔터테인먼트 만족도가 높을수록 만족과 불만족의 비율차이가 크다.

# %%
col=['Online support', 'Ease of Online booking',
       'On-board service', 'Leg room service', 'Baggage handling',
       'Checkin service', 'Cleanliness', 'Online boarding']

# %%
plt.figure(figsize=(12,8))
for i,colname in enumerate(col):
  plt.subplot(2,4,i+1)
  sns.countplot(data=train,x=colname,hue='target')
plt.tight_layout()
plt.show()

# %%
train.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Seat comfort', 'Departure/Arrival time convenient',
#        'Food and drink', 'Gate location', 'Inflight wifi service',
#        'Inflight entertainment', 'Online support', 'Ease of Online booking',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'target'],
#       dtype='object')

# %%
num=['Age','Flight Distance','Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %%
plt.figure(figsize=(12,8))
for i,colname in enumerate(num):
  plt.subplot(2,2,i+1)
  sns.histplot(data=train,x=colname,hue='target')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
for i,colname in enumerate(num):
  plt.subplot(2,2,i+1)
  sns.boxplot(data=train,y=colname,x='target')
plt.tight_layout()
plt.show()

# %%
#나이와 customer type의 관계
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(data=train,x='Age',hue='Customer Type')
plt.subplot(1,2,2)
sns.boxplot(data=train,y='Age',x='Customer Type')

# %%
#나이와 class의 관계
#나이와 customer type의 관계
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(data=train,x='Age',hue='Class')
plt.subplot(1,2,2)
sns.boxplot(data=train,y='Age',x='Class')

# %%
#Type of Travel와 Seat comfort의 관계
sns.countplot(data=train,x='Type of Travel',hue='Seat comfort')

# %%
#Departure Delay in Minutes와 Arrival Delay in Minutes의 관계
sns.lineplot(data=train,
             x='Departure Delay in Minutes',
             y='Arrival Delay in Minutes')

# %% [markdown]
# 거의 선형성을 띈다. 컬럼 하나는 삭제해버릴거임

# %% [markdown]
# ## 전처리
#
# - object 형식 int형으로 바꾸기
# - 이상치 제거
# - 만족도 3이하, 5이상 으로 분리
# - 출발지연시간, 도착 지연시간 중에 하나 삭제

# %% [markdown]
# ### object 형식 int로 바꾸기

# %%
cat_cols=train.select_dtypes('object').columns.tolist()
cat_cols
# Out:
# ['Gender', 'Customer Type', 'Type of Travel', 'Class']

# %%
#원핫인코딩
train=pd.get_dummies(train,columns=cat_cols)
test=pd.get_dummies(test,columns=cat_cols)

# %%
plt.figure(figsize=(12,12))
sns.heatmap(train.corr(),annot=True)

# %% [markdown]
# ### 이상치 제거
#
# - 출발지연시간과 도착 지연 시간 이상치 제거

# %%
def outlier(df=None,column=None,weight=1.5):

  #column 데이터만 추출, 1/4분위와 3/4분위 지점을 np.percentile로 구함. 
  data=df[column]
  quantile_25=np.percentile(data.values,25)
  quantile_75=np.percentile(data.values,75)

  #IQR 구하고 IQR에 1.5를 곲해 최댓값과 최솟값 지점 구하기
  iqr=quantile_75-quantile_25
  iqr_weight=iqr*weight
  lowest_val=quantile_25-iqr_weight#이상치 최소 기준
  highest_val=quantile_75+iqr_weight#이상치 최대 기준

  #최댓값보다 크거나 최솟값보다 작은 값을 아웃라이어로 설정하고  DataFrame index 반환. 
  outlier_index=data[(data < lowest_val) | (data > highest_val)].index

  return outlier_index

# %%
num=['Departure Delay in Minutes','Arrival Delay in Minutes']

# %%
outlier_index={}

for i,colName in enumerate(num):
  outlier_index[i]=outlier(df=train,column=f'{colName}',weight=1.5)
  
outlier_index
# Out:
# {0: Int64Index([  23,   30,   35,   36,   57,   59,   62,   66,   78,   82,
#              ...
#              2954, 2955, 2961, 2966, 2975, 2977, 2982, 2987, 2995, 2997],
#             dtype='int64', length=428),
#  1: Int64Index([   6,   23,   30,   35,   36,   51,   57,   59,   62,   66,
#              ...
#              2945, 2953, 2954, 2955, 2961, 2966, 2977, 2987, 2995, 2997],
#             dtype='int64', length=405)}

# %%
#각각의 숫자들 리스트 안에 넣기
outlier_list=[]

for i in range(len(outlier_index)):
  if list(outlier_index[i].values)==[]:
    continue
  outlier_list.append(list(outlier_index[i].values))
print(outlier_list)
# Out:
# [[23, 30, 35, 36, 57, 59, 62, 66, 78, 82, 85, 92, 116, 132, 151, 160, 161, 162, 170, 175, 198, 202, 206, 214, 241, 247, 255, 258, 270, 275, 279, 283, 285, 290, 292, 303, 309, 325, 335, 340, 341, 356, 359, 368, 369, 373, 375, 377, 384, 385, 391, 394, 416, 428, 429, 435, 454, 457, 472, 483, 490, 510, 517, 522, 537, 539, 543, 563, 575, 578, 587, 592, 599, 604, 620, 621, 623, 624, 627, 638, 641, 650, 652, 668, 670, 672, 691, 693, 695, 696, 701, 703, 715, 721, 737, 752, 762, 763, 766, 773, 783, 792, 797, 798, 799, 810, 824, 828, 837, 840, 852, 858, 862, 869, 883, 884, 895, 901, 904, 906, 912, 923, 937, 947, 948, 949, 958, 968, 978, 983, 987, 993, 999, 1001, 1002, 1011, 1013, 1014, 1020, 1027, 1028, 1031, 1034, 1044, 1052, 1053, 1065, 1068, 1069, 1073, 1074, 1088, 1098, 1102, 1103, 1106, 1116, 1122, 1130, 1138, 1140, 1142, 1177, 1183, 1185, 1187, 1188, 1190, 1191, 1195, 1203, 1222, 1232, 1238, 1242, 1246, 1256, 1259, 1271, 1272, 1274, 1277, 1279, 1300, 1302, 1307, 1310, 1324, 1346, 1356, 1369, 1370, 1383, 1387, 1389, 1393, 1394, 1395, 1399, 1400, 1405, 1411, 1418, 1422, 1432, 1443, 1462, 1476, 1487, 1490, 1491, 1497, 1504, 1510, 1518, 1519, 1525, 1533, 1541, 1548, 1551, 1561, 1576, 1579, 1582, 1588, 1605, 1608, 1612, 1625, 1626, 1630, 1631, 1635, 1655, 1661, 1688, 1691, 1697, 1700, 1705, 1706, 1711, 1718, 1725, 1728, 1731, 1736, 1743, 1745, 1747, 1756, 1761, 1763, 1776, 1788, 1789, 1795, 1797, 1801, 1802, 1803, 1806, 1809, 1815, 1827, 1833, 1837, 1842, 1844, 1847, 1861, 1896, 1897, 1918, 1919, 1931, 1936, 1945, 1953, 1954, 1956, 1969, 1971, 1978, 1979, 1985, 1997, 2009, 2037, 2061, 2065, 2066, 2071, 2100, 2120, 2138, 2144, 2171, 2180, 2198, 2199, 2210, 2213, 2215, 2226, 2239, 2246, 2247, 2252, 2261, 2266, 2267, 2269, 2281, 2291, 2293, 2305, 2310, 2313, 2327, 2328, 2330, 2333, 2334, 2340, 2349, 2351, 2352, 2353, 2358, 2362, 2382, 2387, 2398, 2418, 2424, 2440, 2443, 2446, 2447, 2448, 2449, 2461, 2462, 2466, 2469, 2480, 2484, 2488, 2490, 2495, 2496, 2510, 2511, 2516, 2532, 2535, 2538, 2541, 2542, 2548, 2561, 2563, 2569, 2584, 2592, 2602, 2604, 2617, 2618, 2629, 2635, 2640, 2648, 2653, 2663, 2668, 2674, 2692, 2701, 2711, 2712, 2713, 2714, 2731, 2733, 2734, 2737, 2747, 2753, 2759, 2760, 2761, 2764, 2777, 2784, 2785, 2788, 2798, 2815, 2838, 2850, 2852, 2854, 2862, 2864, 2866, 2871, 2880, 2885, 2899, 2921, 2929, 2930, 2933, 2941, 2953, 2954, 2955, 2961, 2966, 2975, 2977, 2982, 2987, 2995, 2997], [6, 23, 30, 35, 36, 51, 57, 59, 62, 66, 78, 82, 85, 92, 116, 134, 137, 151, 160, 162, 175, 180, 198, 202, 206, 214, 245, 255, 258, 279, 283, 285, 290, 292, 303, 309, 315, 325, 335, 340, 341, 349, 359, 368, 373, 375, 377, 385, 391, 394, 416, 428, 429, 435, 454, 457, 472, 483, 484, 490, 510, 511, 517, 522, 537, 539, 573, 575, 587, 592, 599, 604, 620, 621, 623, 627, 638, 641, 650, 652, 653, 670, 672, 676, 693, 695, 696, 703, 707, 715, 721, 723, 737, 752, 763, 766, 773, 774, 783, 792, 797, 798, 799, 809, 810, 824, 837, 846, 852, 858, 862, 869, 883, 884, 895, 904, 906, 912, 923, 937, 947, 948, 949, 962, 968, 978, 983, 987, 993, 1001, 1002, 1013, 1014, 1020, 1027, 1031, 1034, 1044, 1065, 1068, 1069, 1073, 1074, 1098, 1103, 1116, 1122, 1140, 1151, 1152, 1160, 1177, 1183, 1185, 1187, 1190, 1191, 1195, 1203, 1222, 1238, 1242, 1246, 1252, 1256, 1259, 1271, 1272, 1274, 1277, 1279, 1281, 1300, 1302, 1307, 1309, 1310, 1324, 1346, 1356, 1369, 1370, 1383, 1387, 1389, 1393, 1394, 1395, 1399, 1405, 1407, 1418, 1422, 1432, 1443, 1462, 1476, 1487, 1490, 1491, 1497, 1504, 1510, 1518, 1519, 1525, 1532, 1533, 1541, 1551, 1561, 1562, 1575, 1576, 1579, 1582, 1588, 1605, 1607, 1608, 1612, 1618, 1626, 1630, 1635, 1655, 1661, 1688, 1699, 1700, 1705, 1706, 1711, 1715, 1718, 1725, 1731, 1736, 1743, 1745, 1747, 1756, 1776, 1792, 1795, 1797, 1801, 1802, 1803, 1809, 1820, 1827, 1831, 1833, 1837, 1840, 1842, 1844, 1875, 1886, 1896, 1897, 1918, 1919, 1931, 1936, 1945, 1953, 1954, 1956, 1969, 1978, 1979, 1995, 1997, 2009, 2037, 2061, 2065, 2066, 2088, 2100, 2105, 2120, 2138, 2144, 2 ...

# %%
#리스트 안의 리스트들을 하나로 합치기
outlier_list=sum(outlier_list,[])
print(outlier_list)
print('개수 :',len(outlier_list))

#중복숫자제거
outlier_list=set(outlier_list)
print(outlier_list)
print('개수:',len(outlier_list))

#다시 리스트로 변환
outlier_list=list(outlier_list)
print(type(outlier_list))
print(outlier_list)

# 리스트 숫자 정렬
outlier_list.sort()
print(outlier_list)

#ㅈㅔ거
for i in outlier_list:
  train.drop(i,axis=0,inplace=True)

train.shape
# Out:
# [23, 30, 35, 36, 57, 59, 62, 66, 78, 82, 85, 92, 116, 132, 151, 160, 161, 162, 170, 175, 198, 202, 206, 214, 241, 247, 255, 258, 270, 275, 279, 283, 285, 290, 292, 303, 309, 325, 335, 340, 341, 356, 359, 368, 369, 373, 375, 377, 384, 385, 391, 394, 416, 428, 429, 435, 454, 457, 472, 483, 490, 510, 517, 522, 537, 539, 543, 563, 575, 578, 587, 592, 599, 604, 620, 621, 623, 624, 627, 638, 641, 650, 652, 668, 670, 672, 691, 693, 695, 696, 701, 703, 715, 721, 737, 752, 762, 763, 766, 773, 783, 792, 797, 798, 799, 810, 824, 828, 837, 840, 852, 858, 862, 869, 883, 884, 895, 901, 904, 906, 912, 923, 937, 947, 948, 949, 958, 968, 978, 983, 987, 993, 999, 1001, 1002, 1011, 1013, 1014, 1020, 1027, 1028, 1031, 1034, 1044, 1052, 1053, 1065, 1068, 1069, 1073, 1074, 1088, 1098, 1102, 1103, 1106, 1116, 1122, 1130, 1138, 1140, 1142, 1177, 1183, 1185, 1187, 1188, 1190, 1191, 1195, 1203, 1222, 1232, 1238, 1242, 1246, 1256, 1259, 1271, 1272, 1274, 1277, 1279, 1300, 1302, 1307, 1310, 1324, 1346, 1356, 1369, 1370, 1383, 1387, 1389, 1393, 1394, 1395, 1399, 1400, 1405, 1411, 1418, 1422, 1432, 1443, 1462, 1476, 1487, 1490, 1491, 1497, 1504, 1510, 1518, 1519, 1525, 1533, 1541, 1548, 1551, 1561, 1576, 1579, 1582, 1588, 1605, 1608, 1612, 1625, 1626, 1630, 1631, 1635, 1655, 1661, 1688, 1691, 1697, 1700, 1705, 1706, 1711, 1718, 1725, 1728, 1731, 1736, 1743, 1745, 1747, 1756, 1761, 1763, 1776, 1788, 1789, 1795, 1797, 1801, 1802, 1803, 1806, 1809, 1815, 1827, 1833, 1837, 1842, 1844, 1847, 1861, 1896, 1897, 1918, 1919, 1931, 1936, 1945, 1953, 1954, 1956, 1969, 1971, 1978, 1979, 1985, 1997, 2009, 2037, 2061, 2065, 2066, 2071, 2100, 2120, 2138, 2144, 2171, 2180, 2198, 2199, 2210, 2213, 2215, 2226, 2239, 2246, 2247, 2252, 2261, 2266, 2267, 2269, 2281, 2291, 2293, 2305, 2310, 2313, 2327, 2328, 2330, 2333, 2334, 2340, 2349, 2351, 2352, 2353, 2358, 2362, 2382, 2387, 2398, 2418, 2424, 2440, 2443, 2446, 2447, 2448, 2449, 2461, 2462, 2466, 2469, 2480, 2484, 2488, 2490, 2495, 2496, 2510, 2511, 2516, 2532, 2535, 2538, 2541, 2542, 2548, 2561, 2563, 2569, 2584, 2592, 2602, 2604, 2617, 2618, 2629, 2635, 2640, 2648, 2653, 2663, 2668, 2674, 2692, 2701, 2711, 2712, 2713, 2714, 2731, 2733, 2734, 2737, 2747, 2753, 2759, 2760, 2761, 2764, 2777, 2784, 2785, 2788, 2798, 2815, 2838, 2850, 2852, 2854, 2862, 2864, 2866, 2871, 2880, 2885, 2899, 2921, 2929, 2930, 2933, 2941, 2953, 2954, 2955, 2961, 2966, 2975, 2977, 2982, 2987, 2995, 2997, 6, 23, 30, 35, 36, 51, 57, 59, 62, 66, 78, 82, 85, 92, 116, 134, 137, 151, 160, 162, 175, 180, 198, 202, 206, 214, 245, 255, 258, 279, 283, 285, 290, 292, 303, 309, 315, 325, 335, 340, 341, 349, 359, 368, 373, 375, 377, 385, 391, 394, 416, 428, 429, 435, 454, 457, 472, 483, 484, 490, 510, 511, 517, 522, 537, 539, 573, 575, 587, 592, 599, 604, 620, 621, 623, 627, 638, 641, 650, 652, 653, 670, 672, 676, 693, 695, 696, 703, 707, 715, 721, 723, 737, 752, 763, 766, 773, 774, 783, 792, 797, 798, 799, 809, 810, 824, 837, 846, 852, 858, 862, 869, 883, 884, 895, 904, 906, 912, 923, 937, 947, 948, 949, 962, 968, 978, 983, 987, 993, 1001, 1002, 1013, 1014, 1020, 1027, 1031, 1034, 1044, 1065, 1068, 1069, 1073, 1074, 1098, 1103, 1116, 1122, 1140, 1151, 1152, 1160, 1177, 1183, 1185, 1187, 1190, 1191, 1195, 1203, 1222, 1238, 1242, 1246, 1252, 1256, 1259, 1271, 1272, 1274, 1277, 1279, 1281, 1300, 1302, 1307, 1309, 1310, 1324, 1346, 1356, 1369, 1370, 1383, 1387, 1389, 1393, 1394, 1395, 1399, 1405, 1407, 1418, 1422, 1432, 1443, 1462, 1476, 1487, 1490, 1491, 1497, 1504, 1510, 1518, 1519, 1525, 1532, 1533, 1541, 1551, 1561, 1562, 1575, 1576, 1579, 1582, 1588, 1605, 1607, 1608, 1612, 1618, 1626, 1630, 1635, 1655, 1661, 1688, 1699, 1700, 1705, 1706, 1711, 1715, 1718, 1725, 1731, 1736, 1743, 1745, 1747, 1756, 1776, 1792, 1795, 1797, 1801, 1802, 1803, 1809, 1820, 1827, 1831, 1833, 1837, 1840, 1842, 1844, 1875, 1886, 1896, 1897, 1918, 1919, 1931, 1936, 1945, 1953, 1954, 1956, 1969, 1978, 1979, 1995, 1997, 2009, 2037, 2061, 2065, 2066, 2088, 2100, 2105, 2120, 2138, 2144, 2171 ...
# 개수 : 833
# {6, 2061, 2065, 2066, 23, 2071, 30, 35, 36, 2088, 51, 2100, 57, 2105, 59, 62, 66, 2120, 78, 82, 85, 2138, 92, 2144, 116, 2171, 132, 2180, 134, 137, 2198, 151, 2199, 160, 161, 162, 2210, 2213, 2215, 170, 175, 2226, 180, 2239, 198, 2246, 2247, 202, 2252, 206, 2261, 214, 2266, 2267, 2269, 2281, 241, 2291, 2293, 245, 247, 255, 2305, 258, 2310, 2313, 270, 275, 279, 2327, 2328, 2330, 283, 285, 2333, 2334, 2337, 290, 292, 2340, 2349, 303, 2351, 2352, 2353, 309, 2358, 2357, 2362, 315, 2370, 325, 2382, 335, 2387, 340, 341, 2389, 349, 2398, 356, 359, 368, 369, 2418, 373, 375, 2424, 377, 384, 385, 2437, 391, 2440, 394, 2443, 2446, 2447, 2448, 2449, 2461, 2462, 416, 2466, 2469, 428, 429, 2480, 435, 2484, 2488, 2489, 2490, 2495, 2496, 454, 457, 2510, 2511, 2516, 472, 483, 2532, 484, 2535, 490, 2538, 2541, 2542, 2548, 510, 511, 2561, 2563, 517, 2569, 522, 2576, 2581, 2584, 537, 539, 543, 2592, 2602, 2604, 563, 2617, 2618, 573, 575, 2624, 578, 2629, 587, 2635, 592, 2640, 2644, 599, 2648, 2649, 604, 2653, 2663, 620, 621, 2668, 623, 624, 2674, 627, 638, 641, 2692, 650, 652, 2701, 653, 2711, 2712, 2713, 2714, 668, 670, 672, 676, 2731, 2733, 2734, 2737, 691, 693, 695, 696, 2747, 701, 703, 2753, 707, 2755, 2759, 2760, 2761, 715, 2764, 721, 723, 2777, 2784, 737, 2785, 2787, 2788, 2798, 752, 762, 763, 766, 2815, 773, 774, 783, 2838, 792, 797, 798, 799, 2850, 2852, 2853, 2854, 809, 810, 2862, 2864, 2866, 2871, 824, 828, 2880, 837, 2885, 840, 846, 2899, 852, 858, 862, 869, 2921, 2929, 2930, 883, 884, 2933, 2941, 895, 2945, 901, 904, 2953, 906, 2954, 2955, 912, 2961, 2966, 923, 2975, 2977, 2982, 937, 2987, 947, 948, 949, 2995, 2997, 958, 962, 968, 978, 983, 987, 993, 999, 1001, 1002, 1011, 1013, 1014, 1020, 1027, 1028, 1031, 1034, 1044, 1052, 1053, 1065, 1068, 1069, 1073, 1074, 1088, 1098, 1102, 1103, 1106, 1116, 1122, 1130, 1138, 1140, 1142, 1151, 1152, 1160, 1177, 1183, 1185, 1187, 1188, 1190, 1191, 1195, 1203, 1222, 1232, 1238, 1242, 1246, 1252, 1256, 1259, 1271, 1272, 1274, 1277, 1279, 1281, 1300, 1302, 1307, 1309, 1310, 1324, 1346, 1356, 1369, 1370, 1383, 1387, 1389, 1393, 1394, 1395, 1399, 1400, 1405, 1407, 1411, 1418, 1422, 1432, 1443, 1462, 1476, 1487, 1490, 1491, 1497, 1504, 1510, 1518, 1519, 1525, 1532, 1533, 1541, 1548, 1551, 1561, 1562, 1575, 1576, 1579, 1582, 1588, 1605, 1607, 1608, 1612, 1618, 1625, 1626, 1630, 1631, 1635, 1655, 1661, 1688, 1691, 1697, 1699, 1700, 1705, 1706, 1711, 1715, 1718, 1725, 1728, 1731, 1736, 1743, 1745, 1747, 1756, 1761, 1763, 1776, 1788, 1789, 1792, 1795, 1797, 1801, 1802, 1803, 1806, 1809, 1815, 1820, 1827, 1831, 1833, 1837, 1840, 1842, 1844, 1847, 1861, 1875, 1886, 1896, 1897, 1918, 1919, 1931, 1936, 1945, 1953, 1954, 1956, 1969, 1971, 1978, 1979, 1985, 1995, 1997, 2009, 2037}
# 개수: 485
# <class 'list'>
# [6, 2061, 2065, 2066, 23, 2071, 30, 35, 36, 2088, 51, 2100, 57, 2105, 59, 62, 66, 2120, 78, 82, 85, 2138, 92, 2144, 116, 2171, 132, 2180, 134, 137, 2198, 151, 2199, 160, 161, 162, 2210, 2213, 2215, 170, 175, 2226, 180, 2239, 198, 2246, 2247, 202, 2252, 206, 2261, 214, 2266, 2267, 2269, 2281, 241, 2291, 2293, 245, 247, 255, 2305, 258, 2310, 2313, 270, 275, 279, 2327, 2328, 2330, 283, 285, 2333, 2334, 2337, 290, 292, 2340, 2349, 303, 2351, 2352, 2353, 309, 2358, 2357, 2362, 315, 2370, 325, 2382, 335, 2387, 340, 341, 2389, 349, 2398, 356, 359, 368, 369, 2418, 373, 375, 2424, 377, 384, 385, 2437, 391, 2440, 394, 2443, 2446, 2447, 2448, 2449, 2461, 2462, 416, 2466, 2469, 428, 429, 2480, 435, 2484, 2488, 2489, 2490, 2495, 2496, 454, 457, 2510, 2511, 2516, 472, 483, 2532, 484, 2535, 490, 2538, 2541, 2542, 2548, 510, 511, 2561, 2563, 517, 2569, 522, 2576, 2581, 2584, 537, 539, 543, 2592, 2602, 2604, 563, 2617, 2618, 573, 575, 2624, 578, 2629, 587, 2635, 592, 2640, 2644, 599, 2648, 2649, 604, 2653, 2663, 620, 621, 2668, 623, 624, 2674, 627, 638, 641, 2692, 650, 652, 2701, 653, 2711, 2712, 2713, 2714, 668, 670, 672, 676, 2731, 2733, 2734, 2737, 691, 693, 695, 696, 2747, 701, 703, 2753, 707, 2755, 2759, 2760, 2761, 715, 2764, 721, 723, 2777, 2784, 737, 2785, 2787, 2788, 2798, 752, 762, 763, 766, 2815, 773, 774, 783, 2838, 792, 797, 798, 799, 2850, 2852, 2853, 2854, 809, 810, 2862, 2864, 2866, 2871, 824, 828, 2880, 837, 2885, 840, 846, 2899, 852, 858, 862, 869, 2921, 2929, 2930, 883, 884, 2933, 2941, 895, 2945, 901, 904, 2953, 906, 2954, 2955, 912, 2961, 2966, 923, 2975, 2977, 2982, 937, 2987, 947, 948, 949, 2995, 2997, 958, 962, 968, 978, 983, 987, 993, 999, 1001, 1002, 1011, 1013, 1014, 1020, 1027, 1028, 1031, 1034, 1044, 1052, 1053, 1065, 1068, 1069, 1073, 1074, 1088, 1098, 1102, 1103, 1106, 1116, 1122, 1130, 1138, 1140, 1142, 1151, 1152, 1160, 1177, 1183, 1185, 1187, 1188, 1190, 1191, 1195, 1203, 1222, 1232, 1238, 1242, 1246, 1252, 1256, 1259, 1271, 1272, 1274, 1277, 1279, 1281, 1300, 1302, 1307, 1309, 1310, 1324, 1346, 1356, 1369, 1370, 1383, 1387, 1389, 1393, 1394, 1395, 1399, 1400, 1405, 1407, 1411, 1418, 1422, 1432, 1443, 1462, 1476, 1487, 1490, 1491, 1497, 1504, 1510, 1518, 1519, 1525, 1532, 1533, 1541, 1548, 1551, 1561, 1562, 1575, 1576, 1579, 1582, 1588, 1605, 1607, 1608, 1612, 1618, 1625, 1626, 1630, 1631, 1635, 1655, 1661, 1688, 1691, 1697, 1699, 1700, 1705, 1706, 1711, 1715, 1718, 1725, 1728, 1731, 1736, 1743, 1745, 1747, 1756, 1761, 1763, 1776, 1788, 1789, 1792, 1795, 1797, 1801, 1802, 1803, 1806, 1809, 1815, 1820, 1827, 1831, 1833, 1837, 1840, 1842, 1844, 1847, 1861, 1875, 1886, 1896, 1897, 1918, 1919, 1931, 1936, 1945, 1953, 1954, 1956, 1969, 1971, 1978, 1979, 1985, 1995, 1997, 2009, 2037]
# [6, 23, 30, 35, 36, 51, 57, 59, 62, 66, 78, 82, 85, 92, 116, 132, 134, 137, 151, 160, 161, 162, 170, 175, 180, 198, 202, 206, 214, 241, 245, 247, 255, 258, 270, 275, 279, 283, 285, 290, 292, 303, 309, 315, 325, 335, 340, 341, 349, 356, 359, 368, 369, 373, 375, 377, 384, 385, 391, 394, 416, 428, 429, 435, 454, 457, 472, 483, 484, 490, 510, 511, 517, 522, 537, 539, 543, 563, 573, 575, 578, 587, 592, 599, 604, 620, 621, 623, 624, 627, 638, 641, 650, 652, 653, 668, 670, 672, 676, 691, 693, 695, 696, 701, 703, 707, 715, 721, 723, 737, 752, 762, 763, 766, 773, 774, 783, 792, 797, 798, 799, 809, 810, 824, 828, 837, 840, 846, 852, 858, 862, 869, 883, 884, 895, 901, 904, 906, 912, 923, 937, 947, 948, 949, 958, 962, 968, 978, 983, 987, 993, 999, 1001, 1002, 1011, 1013, 1014, 1020, 1027, 1028, 1031, 1034, 1044, 1052, 1053, 1065, 1068, 1069, 1073, 1074, 1088, 1098, 1102, 1103, 1106, 1116, 1122, 1130, 1138, 1140, 1142, 1151, 1152, 1160, 1177, 1183, 1185, 1187, 1188, 1190, 1191, 1195, 1203, 1222, 1232, 1238, 1242, 1246, 1252, 1256, 1259, 1271, 1272, 1274, 1277, 1279, 1281, 1300, 1302, 1307, 1309, 1310, 1324, 1346, 1356, 1369, 1370, 1383, 1387, 1389, 1393, 1394, 1395, 1399, 1400, 1405, 1407, 1411, 1418, 1422, 1432, 1443, 1462, 1476, 1487, 1490, 1491, 1497, 1504, 1510, 1518, 1519, 1525, 1532, 1533, 1541, 1548, 1551, 1561, 1562, 1575, 1576, 1579, 1582, 1588, 1605, 1607, 1608, 1612, 1618, 1625, 1626, 1630, 1631, 1635, 1655, 1661, 1688, 1691, 1697, 1699, 1700, 1705, 1706, 1711, 1715, 1718, 1725, 1728, 1731, 1736, 1743, 1745, 1747, 1756, 1761, 1763, 1776, 1788, 1789, 1792, 1795, 1797, 1801, 1802, 1803, 1806, 1809, 1815, 1820, 1827, 1831, 1833, 1837, 1840, 1842, 1844, 1847, 1861, 1875, 1886, 1896, 1897, 1918, 1919, 1931, 1936, 1945, 1953, 1954, 1956, 1969, 1971, 1978, 1979, 1985, 1995, 1997, 2009, 2037, 2061, 2065, 2066, 2071, 2088, 2100, 2105, 2120, 2138, 2144, 2171, 2180, 2198, 2199, 2210, 2213, 2215, 2226, 2239, 2246, 2247, 2252, 2261, 2266, 2267, 2269, 2281, 2291, 2293, 2305, 2310, 2313, 2327, 2328, 2330, 2333, 2334, 2337, 2340, 2349, 2351, 2352, 2353, 2357, 2358, 2362, 2370, 2382, 2387, 2389, 2398, 2418, 2424, 2437, 2440, 2443, 2446, 2447, 2448, 2449, 2461, 2462, 2466, 2469, 2480, 2484, 2488, 2489, 2490, 2495, 2496, 2510, 2511, 2516, 2532, 2535, 2538, 2541, 2542, 2548, 2561, 2563, 2569, 2576, 2581, 2584, 2592, 2602, 2604, 2617, 2618, 2624, 2629, 2635, 2640, 2644, 2648, 2649, 2653, 2663, 2668, 2674, 2692, 2701, 2711, 2712, 2713, 2714, 2731, 2733, 2734, 2737, 2747, 2753, 2755, 2759, 2760, 2761, 2764, 2777, 2784, 2785, 2787, 2788, 2798, 2815, 2838, 2850, 2852, 2853, 2854, 2862, 2864, 2866, 2871, 2880, 2885, 2899, 2921, 2929, 2930, 2933, 2941, 2945, 2953, 2954, 2955, 2961, 2966, 2975, 2977, 2982, 2987, 2995, 2997]
# (2515, 28)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2515 entries, 0 to 2999
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                2515 non-null   int64
#  1   Flight Distance                    2515 non-null   int64
#  2   Seat comfort                       2515 non-null   int64
#  3   Departure/Arrival time convenient  2515 non-null   int64
#  4   Food and drink                     2515 non-null   int64
#  5   Gate location                      2515 non-null   int64
#  6   Inflight wifi service              2515 non-null   int64
#  7   Inflight entertainment             2515 non-null   int64
#  8   Online support                     2515 non-null   int64
#  9   Ease of Online booking             2515 non-null   int64
#  10  On-board service                   2515 non-null   int64
#  11  Leg room service                   2515 non-null   int64
#  12  Baggage handling                   2515 non-null   int64
#  13  Checkin service                    2515 non-null   int64
#  14  Cleanliness                        2515 non-null   int64
#  15  Online boarding                    2515 non-null   int64
#  16  Departure Delay in Minutes         2515 non-null   int64
#  17  Arrival Delay in Minutes           2515 non-null   float64
#  18  target                             2515 non-null   int64
#  19  Gender_Female                      2515 non-null   uint8
#  20  Gender_Male                        2515 non-null   uint8
#  21  Customer Type_Loyal Customer       2515 non-null   uint8
#  22  Customer Type_disloyal Customer    2515 non-null   uint8
#  23  Type of Travel_Business travel     2515 non-null   uint8
#  24  Type of Travel_Personal Travel     2515 non-null   uint8
#  25  Class_Business                     2515 non-null   uint8
#  26  Class_Eco                          2515 non-null   uint8
#  27  Class_Eco Plus                     2515 non-null   uint8
# dtypes: float64(1), int64(18), uint8(9)
# memory usage: 479.6 KB

# %%
X_train=train.drop('target',axis=1)
y_train=train['target']
X_test=test

# %% [markdown]
# ## 모델링

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import GridSearchCV
 
estimators=[]

rf=RandomForestClassifier()
estimators.append(rf)

xgb=XGBClassifier()
estimators.append(xgb)

etr=ExtraTreesClassifier()
estimators.append(etr)

#모듈의 파라미터들을 할당할 리스트 만들어주기
params=[]

params_rf={
    'n_estimators':[90,100,200,300],
    'min_samples_split':[1,2,3,4]
}
params.append(params_rf)

params_xgb={'n_estimatros':[100,300,500],
            'learning_rate':[0.05,0.1,0.3],
            'max_depth':[3,5,7],
            'subsample':[0.1,0.3]}

params.append(params_xgb)

params_etr={
    'n_estimators':[50,60,70,80,90,100,110,120,130,140,150]
}
params.append(params_etr)

# %%
from tqdm.auto import tqdm

def gridSearchCV(models,params):
  best_models=[]

  for i in tqdm(range(0,len(models))):
    model_grid=GridSearchCV(models[i],params[i],n_jobs=-1,verbose=1,cv=5)
    model_grid.fit(X_train,y_train)
    best_models.append(model_grid.best_estimator_)
  return best_models

best_model_list=gridSearchCV(estimators,params)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Fitting 5 folds for each of 11 candidates, totalling 55 fits

# %%
best_model_list
# Out:
# [RandomForestClassifier(),
#  XGBClassifier(max_depth=7, n_estimatros=100, subsample=0.3),
#  ExtraTreesClassifier(n_estimators=150)]

# %%
best_models=[
             ('rf',RandomForestClassifier()),
             ('xgb',XGBClassifier(max_depth=7, n_estimatros=100, subsample=0.3)),
             ('ex', ExtraTreesClassifier(n_estimators=150))
]

from sklearn.ensemble import VotingClassifier

voting=VotingClassifier(estimators=best_models)
voting.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('rf', RandomForestClassifier()),
#                              ('xgb',
#                               XGBClassifier(max_depth=7, n_estimatros=100,
#                                             subsample=0.3)),
#                              ('ex', ExtraTreesClassifier(n_estimators=150))])

# %%
pred=voting.predict(X_test)
pred
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %%
sample
# Out:
#         id  target
# 0        1       0
# 1        2       0
# 2        3       0
# 3        4       0
# 4        5       0
# ...    ...     ...
# 1995  1996       0
# 1996  1997       0
# 1997  1998       0
# 1998  1999       0
# 1999  2000       0
#
# [2000 rows x 2 columns]

# %%
submit=sample.copy()
submit['target']=pred
submit.to_csv('submit.csv',index=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
